# %%
l1=[10,20,30,40]
l2=[1,2,3,4]
l=[]
#l= [11,22,33,44]

for i,j in zip(l1,l2):
    l.append(i+j)

print(l)
# Out:
# [11, 22, 33, 44]

# %%
l=[i+j for i,j in zip(l1,l2)]

# %%
l
# Out:
# [11, 22, 33, 44]

# %%
l1+l2
# Out:
# [10, 20, 30, 40, 1, 2, 3, 4]

# %%
import numpy as np

# %%
arr1= np.array(l1)

# %%
type(arr1)
# Out:
# numpy.ndarray

# %%
arr2= np.array(l2)

# %%
arr2
# Out:
# array([1, 2, 3, 4])

# %%
print('arr1: ', arr1)
# Out:
# arr1:  [10 20 30 40]

# %%
print('arr2: ', arr2)
# Out:
# arr2:  [1 2 3 4]

# %%
arr1+arr2
# Out:
# array([11, 22, 33, 44])

# %%
l1*l2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 l1*l2
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
arr1*arr2
# Out:
# array([ 10,  40,  90, 160])

# %%
print(arr1+arr2)
# Out:
# [11 22 33 44]

# %%
print(arr1/arr2)
# Out:
# [10. 10. 10. 10.]

# %%
print(arr1%arr2)
# Out:
# [0 0 0 0]

# %%
print(arr1 - arr2)
# Out:
# [ 9 18 27 36]

# %% [markdown]
# **Use Case2**

# %%
import time
start= time.time()
l1= list(range(1,1000000))
l2= list(range(1,1000000))
mul=[i*j for i,j in zip(l1,l2)]
end= time.time()
print(end- start)
# Out:
# 0.20082569122314453

# %%
import time
import numpy as np
start= time.time()
arr1= np.arange(1,100000000)
arr2= np.arange(1,100000000)
mul= arr1*arr2
end= time.time()
print(end- start)
# Out:
# 0.8254637718200684

# %%
import time
start=time.time()
l1=list(range(1,100000000))
l2=list(range(1,000000000))
mul=[i*j for i,j in zip(l1,l2)]
end=time.time()
print("total time taken is:",(end-start))
# Out:
# total time taken is: 2.7919692993164062
